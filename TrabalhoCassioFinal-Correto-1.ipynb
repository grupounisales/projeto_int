# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import json

df = pd.read_csv('C:/Users/Thiago/OneDrive/Área de Trabalho/arquivo/ANIMES21.csv',dtype=str)

# %%
url = "https://servicodados.ibge.gov.br/api/v1/localidades/estados/ES/municipios"

# %%
json = pd.read_json(url, dtype=str)

# %%
print(json)
# Out:
#          id                nome  \
# 0   3200102      Afonso Cláudio
# 1   3200136        Águia Branca
# 2   3200169  Água Doce do Norte
# 3   3200201              Alegre
# 4   3200300      Alfredo Chaves
# ..      ...                 ...
# 73  3205101               Viana
# 74  3205150          Vila Pavão
# 75  3205176        Vila Valério
# 76  3205200          Vila Velha
# 77  3205309             Vitória
#
#                                          microrregiao  \
# 0   {'id': 32007, 'nome': 'Afonso Cláudio', 'mesor...
# 1   {'id': 32002, 'nome': 'Nova Venécia', 'mesorre...
# 2   {'id': 32001, 'nome': 'Barra de São Francisco'...
# 3   {'id': 32011, 'nome': 'Alegre', 'mesorregiao':...
# 4   {'id': 32010, 'nome': 'Guarapari', 'mesorregia...
# ..                                                ...
# 73  {'id': 32009, 'nome': 'Vitória', 'mesorregiao'...
# 74  {'id': 32002, 'nome': 'Nova Venécia', 'mesorre...
# 75  {'id': 32002, 'nome': 'Nova Venécia', 'mesorre...
# ...

# %%
df.head()
# Out:
#   TP_NOT ID_AGRAVO DT_NOTIFIC SEM_NOT NU_ANO SG_UF_NOT ID_MUNICIP ID_REGIONA  \
# 0      2       X29   20210105  202101   2021        52     520060       1784
# 1      2       X29   20210110  202102   2021        31     314630       1465
# 2      2       X29   20210117  202103   2021        31     315430       1471
# 3      2       X29   20210118  202103   2021        31     313770       1454
# 4      2       X29   20210123  202103   2021        31     312420       1454
#
#   DT_SIN_PRI SEM_PRI  ... COM_SISTEM COM_RENAL COM_EDEMA COM_SEPTIC  \
# 0   20201204  202049  ...          2       NaN       NaN        NaN
# 1   20210110  202102  ...          2       NaN       NaN        NaN
# 2   20210117  202103  ...          2       NaN       NaN        NaN
# 3   20210118  202103  ...        NaN       NaN       NaN        NaN
# 4   20210123  202103  ...          2       NaN       NaN        NaN
#
#   COM_CHOQUE DOENCA_TRA EVOLUCAO  DT_OBITO DT_ENCERRA DT_DIGITA
# ...

# %%
json.rename(columns = {"id":"ID_MUNICIP"})
# Out:
#    ID_MUNICIP                nome  \
# 0     3200102      Afonso Cláudio
# 1     3200136        Águia Branca
# 2     3200169  Água Doce do Norte
# 3     3200201              Alegre
# 4     3200300      Alfredo Chaves
# ..        ...                 ...
# 73    3205101               Viana
# 74    3205150          Vila Pavão
# 75    3205176        Vila Valério
# 76    3205200          Vila Velha
# 77    3205309             Vitória
#
#                                          microrregiao  \
# 0   {'id': 32007, 'nome': 'Afonso Cláudio', 'mesor...
# 1   {'id': 32002, 'nome': 'Nova Venécia', 'mesorre...
# 2   {'id': 32001, 'nome': 'Barra de São Francisco'...
# 3   {'id': 32011, 'nome': 'Alegre', 'mesorregiao':...
# 4   {'id': 32010, 'nome': 'Guarapari', 'mesorregia...
# ..                                                ...
# 73  {'id': 32009, 'nome': 'Vitória', 'mesorregiao'...
# 74  {'id': 32002, 'nome': 'Nova Venécia', 'mesorre...
# 75  {'id': 32002, 'nome': 'Nova Venécia', 'mesorre...
# ...

# %%
pd.concat([json,df],axis = 1)
# Out:
#          id                nome  \
# 0   3200102      Afonso Cláudio
# 1   3200136        Águia Branca
# 2   3200169  Água Doce do Norte
# 3   3200201              Alegre
# 4   3200300      Alfredo Chaves
# ..      ...                 ...
# 73  3205101               Viana
# 74  3205150          Vila Pavão
# 75  3205176        Vila Valério
# 76  3205200          Vila Velha
# 77  3205309             Vitória
#
#                                          microrregiao  \
# 0   {'id': 32007, 'nome': 'Afonso Cláudio', 'mesor...
# 1   {'id': 32002, 'nome': 'Nova Venécia', 'mesorre...
# 2   {'id': 32001, 'nome': 'Barra de São Francisco'...
# 3   {'id': 32011, 'nome': 'Alegre', 'mesorregiao':...
# 4   {'id': 32010, 'nome': 'Guarapari', 'mesorregia...
# ..                                                ...
# 73  {'id': 32009, 'nome': 'Vitória', 'mesorregiao'...
# 74  {'id': 32002, 'nome': 'Nova Venécia', 'mesorre...
# 75  {'id': 32002, 'nome': 'Nova Venécia', 'mesorre...
# ...

# %%
df.isnull() #Retorna um objeto booleano de mesmo tamanho indicando se os valores são NA. Valores NA, como Nenhum ou numpy.NaN
# Out:
#    TP_NOT  ID_AGRAVO  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP  \
# 0   False      False       False    False   False      False       False
# 1   False      False       False    False   False      False       False
# 2   False      False       False    False   False      False       False
# 3   False      False       False    False   False      False       False
# 4   False      False       False    False   False      False       False
# 5   False      False       False    False   False      False       False
#
#    ID_REGIONA  DT_SIN_PRI  SEM_PRI  ...  COM_SISTEM  COM_RENAL  COM_EDEMA  \
# 0       False       False    False  ...       False       True       True
# 1       False       False    False  ...       False       True       True
# 2       False       False    False  ...       False       True       True
# 3       False       False    False  ...        True       True       True
# 4       False       False    False  ...       False       True       True
# ...

# %%
df.isnull().sum() / df.shape[0] * 100 #retorna o número de valores ausentes para cada coluna retorna %.
# Out:
# TP_NOT         0.000000
# ID_AGRAVO      0.000000
# DT_NOTIFIC     0.000000
# SEM_NOT        0.000000
# NU_ANO         0.000000
#                 ...
# DOENCA_TRA    16.666667
# EVOLUCAO      16.666667
# DT_OBITO       0.000000
# DT_ENCERRA     0.000000
# DT_DIGITA      0.000000
# Length: 77, dtype: float64

# %%
(df[['CLI_HEMORR','ANI_LAGART','NU_AMPO_7','NU_AMPOL_4','ANT_LOCALI','NU_AMPOL_6','NU_AMPOL_8','NU_AMPOL_1','NU_AMPOLAS','ANI_ARANHA']].isnull().sum() /df.shape[0]) * 100
# Out:
# CLI_HEMORR    100.0
# ANI_LAGART    100.0
# NU_AMPO_7     100.0
# NU_AMPOL_4    100.0
# ANT_LOCALI    100.0
# NU_AMPOL_6    100.0
# NU_AMPOL_8    100.0
# NU_AMPOL_1    100.0
# NU_AMPOLAS    100.0
# ANI_ARANHA    100.0
# dtype: float64

# %%
df.isnull().sum().sum()#retorna o número total de valores ausentes.
# Out:
# 197

# %%
df[["DT_NOTIFIC", "DT_ENCERRA","DT_DIGITA"]] = df[["DT_NOTIFIC", "DT_ENCERRA","DT_DIGITA"]].apply(pd.to_datetime, errors='coerce', format='%Y%m%d')

# %%
df.head()
# Out:
#   TP_NOT ID_AGRAVO DT_NOTIFIC SEM_NOT NU_ANO SG_UF_NOT ID_MUNICIP ID_REGIONA  \
# 0      2       X29 2021-01-05  202101   2021        52     520060       1784
# 1      2       X29 2021-01-10  202102   2021        31     314630       1465
# 2      2       X29 2021-01-17  202103   2021        31     315430       1471
# 3      2       X29 2021-01-18  202103   2021        31     313770       1454
# 4      2       X29 2021-01-23  202103   2021        31     312420       1454
#
#   DT_SIN_PRI SEM_PRI  ... COM_SISTEM COM_RENAL COM_EDEMA COM_SEPTIC  \
# 0   20201204  202049  ...          2       NaN       NaN        NaN
# 1   20210110  202102  ...          2       NaN       NaN        NaN
# 2   20210117  202103  ...          2       NaN       NaN        NaN
# 3   20210118  202103  ...        NaN       NaN       NaN        NaN
# 4   20210123  202103  ...          2       NaN       NaN        NaN
#
#   COM_CHOQUE DOENCA_TRA EVOLUCAO  DT_OBITO DT_ENCERRA  DT_DIGITA
# ...

# %%
plt.style.use("ggplot")
plt.figure(figsize = (20, 12))
df["DT_NOTIFIC"].hist(bins = 20, ec = "k", alpha = .7, color = "royalblue")
plt.title("Data Notificações de doenças e mortes")
plt.xlabel("DT_OBITO")
plt.ylabel("DT_ENCERRA")
# Out:
# Text(0, 0.5, 'DT_ENCERRA')

# %%
plt.plot(df["DT_NOTIFIC"])
plt.show()

# %%
plt.hist(df["ID_MUNICIP"],bins=20)
plt.show()

# %%
plt.pie(df["ID_MUNICIP"], labels= df["DT_NOTIFIC"], autopct="%1.0f%%")
plt.show()

# %%
df.head()
# Out:
#   TP_NOT ID_AGRAVO DT_NOTIFIC SEM_NOT NU_ANO SG_UF_NOT ID_MUNICIP ID_REGIONA  \
# 0      2       X29 2021-01-05  202101   2021        52     520060       1784
# 1      2       X29 2021-01-10  202102   2021        31     314630       1465
# 2      2       X29 2021-01-17  202103   2021        31     315430       1471
# 3      2       X29 2021-01-18  202103   2021        31     313770       1454
# 4      2       X29 2021-01-23  202103   2021        31     312420       1454
#
#   DT_SIN_PRI SEM_PRI  ... COM_SISTEM COM_RENAL COM_EDEMA COM_SEPTIC  \
# 0   20201204  202049  ...          2       NaN       NaN        NaN
# 1   20210110  202102  ...          2       NaN       NaN        NaN
# 2   20210117  202103  ...          2       NaN       NaN        NaN
# 3   20210118  202103  ...        NaN       NaN       NaN        NaN
# 4   20210123  202103  ...          2       NaN       NaN        NaN
#
#   COM_CHOQUE DOENCA_TRA EVOLUCAO  DT_OBITO DT_ENCERRA  DT_DIGITA
# ...

# %%
df.columns.values # Mostrar todas as colunas da tabela do Csv
# Out:
# array(['TP_NOT', 'ID_AGRAVO', 'DT_NOTIFIC', 'SEM_NOT', 'NU_ANO',
#        'SG_UF_NOT', 'ID_MUNICIP', 'ID_REGIONA', 'DT_SIN_PRI', 'SEM_PRI',
#        'DT_NASC', 'NU_IDADE_N', 'CS_SEXO', 'CS_GESTANT', 'CS_RACA',
#        'CS_ESCOL_N', 'SG_UF', 'ID_MN_RESI', 'ID_RG_RESI', 'ID_PAIS',
#        'DT_INVEST', 'ID_OCUPA_N', 'ANT_DT_ACI', 'ANT_UF', 'ANT_MUNIC_',
#        'ANT_LOCALI', 'ANT_ZONA', 'ANT_TEMPO_', 'ANT_LOCA_1', 'MCLI_LOCAL',
#        'CLI_DOR', 'CLI_EDEMA', 'CLI_EQUIMO', 'CLI_NECROS', 'CLI_LOCAL_',
#        'CLI_LOCA_1', 'MCLI_SIST', 'CLI_NEURO', 'CLI_HEMORR', 'CLI_VAGAIS',
#        'CLI_MIOLIT', 'CLI_RENAL', 'CLI_OUTR_2', 'CLI_OUTR_3',
#        'CLI_TEMPO_', 'TP_ACIDENT', 'ANI_TIPO_1', 'ANI_SERPEN',
#        'ANI_ARANHA', 'ANI_LAGART', 'TRA_CLASSI', 'CON_SOROTE',
#        'NU_AMPOLAS', 'NU_AMPOL_1', 'NU_AMPOL_8', 'NU_AMPOL_6',
#        'NU_AMPOL_4', 'NU_AMPO_7', 'NU_AMPO_5', 'NU_AMPOL_9', 'NU_AMPOL_3',
#        'COM_LOC', 'COM_SECUND', 'COM_NECROS', 'COM_COMPOR', 'COM_DEFICT',
# ...

# %%
df = df.filter(items=['DT_NOTIFIC','DT_ENCERRA','DT_DIGITA']) #Selecionando as colunas para trabalhar

# %%
df
# Out:
#   DT_NOTIFIC DT_ENCERRA  DT_DIGITA
# 0 2021-01-05 2021-01-07 2021-01-07
# 1 2021-01-10 2021-01-10 2021-01-21
# 2 2021-01-17 2021-01-19 2021-01-19
# 3 2021-01-18 2021-01-28 2021-01-28
# 4 2021-01-23 2021-01-23 2021-01-28
# 5 2021-02-25 2021-02-25 2021-03-04

# %%
df.to_csv("TrabalhoCassioFinal-Correto-2")
